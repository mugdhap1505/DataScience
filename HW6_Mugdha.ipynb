# %% [markdown]
# # CPSC6300-001 Applied Data Science - HW6¶

# %% [markdown]
# # Part B. Visually Exploring the Data (50 points)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %% [markdown]
# ## 1. Histograms of Attributes
#
# Finish the following code to plot a histograms of the numerical attributes of the housing data using 50 bins. Set the figure size to  $20×15$  and the layout to  $3×3$ .

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpt
import seaborn as sns

dataset = pd.read_csv("housing.csv")

# %%
sns.set(color_codes=True)
sns.set(style="white", palette="muted")

### BEGIN SOLUTION
quantitative_df=dataset[['longitude','latitude',"housing_median_age","total_rooms","total_bedrooms","population","households"
                       ,"median_income","median_house_value"]]
quantitative_df.hist(layout=(3,3),figsize=(20,15),bins=50)
plt.show()
### END SOLUTION
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027B898BB668>,
# ...
#       dtype=object)

# %% [markdown]
# ## 2. Capped Attributes
#
# List the set of attributes whose values capped along with their lower and upper caps. Present your answer as a dict type, e.g.:
# ```
# {
#     "attribut_a": [10, 1000],
#     "attribute_b": [5, 600]
# }
# ```

# %%
### BEGIN SOLUTION
data=dataset.head()
capped_attributes={}
for col in dataset.columns:
    if dataset[col].dtype == object:
        continue
    temp_list=[dataset[col].min(),dataset[col].max()]
    capped_attributes[col]=temp_list

print (capped_attributes)
### END SOLUTION
capped_attributes
# Out:
# {'longitude': [-124.35, -114.31], 'latitude': [32.54, 41.95], 'housing_median_age': [1.0, 52.0], 'total_rooms': [2.0, 39320.0], 'total_bedrooms': [1.0, 6445.0], 'population': [3.0, 35682.0], 'households': [1.0, 6082.0], 'median_income': [0.4999, 15.0001], 'median_house_value': [14999.0, 500001.0]}
# {'longitude': [-124.35, -114.31],
#  'latitude': [32.54, 41.95],
#  'housing_median_age': [1.0, 52.0],
#  'total_rooms': [2.0, 39320.0],
#  'total_bedrooms': [1.0, 6445.0],
#  'population': [3.0, 35682.0],
#  'households': [1.0, 6082.0],
#  'median_income': [0.4999, 15.0001],
#  'median_house_value': [14999.0, 500001.0]}

# %% [markdown]
# ## 3. Transformed Attribute Values
#
# The values of median_income do not seem to match the actual income distribution in the United States. How do you explan this discrepancy? Write your answer into a block string variable __explain__.

# %%
import math
import numpy as np

# %%
### BEGIN SOLUTION
explain ="""Transform the data to normal distribution"""
### END SOLUTION
print(explain)
# Out:
# Transform the data to normal distribution

# %%
#Taking quantative values
n=dataset[["housing_median_age","total_rooms","total_bedrooms","population","households"
                       ,"median_income","median_house_value"]]
new_A['normalized_median_income']=np.nan

#Applying Central limit theorem for transformation of median_income
new_A['normalized_median_income']=(quantitative_df['median_income']-quantitative_df['median_income'].mean())/(quantitative_df['median_income'].std())
new_A['normalized_median_house_value']=(quantitative_df['median_house_value']-quantitative_df['median_house_value'].mean())/(quantitative_df['median_house_value'].std())

new_A.head()
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## 4. Long Tail Distribution
#
# List at least two attributes whose histograms are tail heavy: they extend much farther to the right than to the left. Save your list into a variable __long_tail_attributes__.

# %%
#Consider only numerical values
numeric_df=dataset[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households"
                       ,"median_income","median_house_value"]]

# %%
#Normalizing by tranformation
normalized_df=(quantitative_df-quantitative_df.mean())/(quantitative_df.std())
normalized_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327803  1.052523            0.982119    -0.804800       -0.970301
# 1  -1.322812  1.043159           -0.607004     2.045841        1.348243
# 2  -1.332794  1.038478            1.856137    -0.535733       -0.825541
# 3  -1.337785  1.038478            1.856137    -0.624199       -0.718750
# 4  -1.337785  1.038478            1.856137    -0.462393       -0.611959
#
#    population  households  median_income  median_house_value
# 0   -0.974405   -0.977009       2.344709            2.129580
# 1    0.861418    1.669921       2.332181            1.314124
# 2   -0.820757   -0.843616       1.782656            1.258663
# 3   -0.766010   -0.733764       0.932945            1.165072
# 4   -0.759828   -0.629142      -0.012881            1.172871

# %%
#Removing Null values
normalized_df.isnull().sum()
normalized_df.fillna(normalized_df.mean(), inplace=True)
normalized_df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
#Plotting with displots()
f, axes = plt.subplots(3, 3, figsize=(20, 15), sharex=True)
sns.distplot( normalized_df["longitude"] , color="blue", ax=axes[0, 0],)
sns.distplot( normalized_df["latitude"] , color="blue", ax=axes[0, 1])
sns.distplot( normalized_df["housing_median_age"] , color="blue", ax=axes[0, 2])
sns.distplot( normalized_df["total_rooms"] , color="blue", ax=axes[1, 0])
sns.distplot( normalized_df["total_bedrooms"] , color="blue", ax=axes[1, 1])
sns.distplot( normalized_df["population"] , color="blue", ax=axes[1, 2])
sns.distplot( normalized_df["households"] , color="blue", ax=axes[2, 0])
sns.distplot( normalized_df["median_income"] , color="blue", ax=axes[2, 1])
sns.distplot( normalized_df["median_house_value"] , color="blue", ax=axes[2, 2])

# %%
#By considering the above representation 

### BEGIN SOLUTION
long_tail_attributes=['houshold','median_income','population','total_bedrooms','total_rooms']
for a in sorted(long_tail_attributes):
    print(a)
### END SOLUTION
# Out:
# houshold
# median_income
# population
# total_bedrooms
# total_rooms

# %% [markdown]
# ## 5. Distribution Plots
#
# Using the distplot() method in the seaborn library to plot the distributions of normalized histograms for median income and normalized mean housing value in a single figure similar to the one shown below (you don't need to make your figure exactly same as this figure).
# <img src="distplot.png">

# %%
quantitative_df=dataset[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households"
                       ,"median_income","median_house_value"]]


normalized_df=(quantitative_df-quantitative_df.mean())/(quantitative_df.std())

# %%
### BEGIN SOLUTION
sns.distplot(normalized_df['median_income'],bins=10)
sns.distplot(normalized_df['median_house_value'],bins=10)

### END SOLUTION

# %% [markdown]
# ## 6. Scatter Matrix
#
# Scatter matrix is a good visualization to check correlations between attributes. Use the seaborn's pairplot() method to plot the scatter matrix of housing data. Before you start, consider the following three hints:
#
# 1. pairplot only applies to numerical attributes.
# 2. pairplot cannot directly handle the NaN value.
# 3. When the dataset is large, the plotting may be slow.
#
# You may preprocess the data going into the pairplot() method by dropping certain columns and rows. Also, since you only want to see an overall trend, it may be efficient to plot a fraction of the datasets.

# %% [markdown]
# m_df includes only numerical attributes specified below from the dataset as pairplot() method applies to only numerical data asn does not handle NaN values.

# %%
#Considering only numerical attributes
m_df=dataset[["longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households"
                       ,"median_income","median_house_value"]]

# %%
### BEGIN SOLUTION
sns.pairplot(m_df.sample(frac=0.01))
### END SOLUTION
# Out:
# E:\Anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# E:\Anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## 7. Correlation Matrix vs Scatter Matrix
#
# a. Compuet the correlation coefficients between each pair of the numerical attributes and save the results to a variable __corr_matrix__.

# %%
### BEGIN SOLUTION
corr = dataset.corr()
corr
### END SOLUTION
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %% [markdown]
# b. Print the top three attributes that have the strongest correlation with median_house_value and the corresponding correlation coefficients.

# %%
### BEGIN SOLUTION
sorted_corr=normalized_df.corr(method ='pearson').unstack().sort_values(kind="quicksort",ascending=False)
sorted_corr=normalized_df.corr(method ='pearson').unstack().sort_values(kind="quicksort",ascending=False)
sorted_corr[9:15]
### END SOLUTION
# Out:
# total_bedrooms  households        0.979728
# households      total_bedrooms    0.979728
# total_rooms     total_bedrooms    0.930380
# total_bedrooms  total_rooms       0.930380
# households      total_rooms       0.918484
# total_rooms     households        0.918484
# dtype: float64

# %% [markdown]
# c. Plot the scatter plot between __median_income__ and __median_house_value__ into a figure of size $10 \times 8$. Use __ocean_proximity__ as __hue__.

# %%
### BEGIN SOLUTION
plt.figure(figsize = (10, 8))
sns.scatterplot(data=dataset,
               x='median_income',
                y='median_house_value',
                hue='ocean_proximity'
              )
plt.title(" median_income vs median_house_value")
plt.xlabel("median_income")
plt.ylabel("median_house_value")


### END SOLUTION
# Out:
# Text(0.5, 1.0, ' median_income vs median_house_value')
# Text(0.5, 0, 'median_income')
# Text(0, 0.5, 'median_house_value')

# %% [markdown]
# ## 8. Visualize Geographical Data (10 points)
#
# When a dataset contains geographical information (latitude and longitude), creating a geographical scatterplot of the data can reveal very useful information.

# %% [markdown]
# a. Create a scatterplot using the __(latitude, longitude)__ as the cordinates, 1/50 of the population as the size of the marker, and the median house value as the color. You can use the "jet" colormap.

# %%
### BEGIN SOLUTION
dataset.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
s=dataset["population"]/50, label="population", figsize=(12,7),
c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
) 
plt.legend()
### END SOLUTION

# %% [markdown]
# b. You can overlay the scatterplot on top of a map of the region. One simplest way to achieve this overlay is to load an map image and then show the image on the same axes which contains the scatterplot. You can pass an argument "zorder=0" to axes.imshow() and "zorder=1" to the scattplot method you have used.
#
# You can use the image "ca.png" for the ca map. To read and show an image, you can use the following method:
# ```
# img = mpt.image.imread("ca.png")
# plt.imshow(img, extent=bounded_box)
# ```

# %%
bounded_box = (dataset.longitude.min(), dataset.longitude.max(), dataset.latitude.min(), dataset.latitude.max())
### BEGIN SOLUTION

img = mpt.image.imread("ca.png")
dataset.plot(kind="scatter",x="longitude",y="latitude",s=dataset["population"]/50,label="population"
             ,c="median_house_value",cmap=plt.get_cmap("jet"),colorbar=True,figsize=(12,7) )


dataset.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
s=dataset["population"]/50, label="population", figsize=(12,7),
c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
) 


plt.imshow(img, extent=bounded_box)
plt.show()

### END SOLUTION

# %% [markdown]
# __End of Part B__.
